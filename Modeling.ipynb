# %%
# !pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in /Users/jacksonglass/Library/r-miniconda/lib/python3.10/site-packages (0.4.2)
# Requirement already satisfied: tqdm in /Users/jacksonglass/Library/r-miniconda/lib/python3.10/site-packages (from kagglehub) (4.65.0)
# Requirement already satisfied: pyyaml in /Users/jacksonglass/Library/r-miniconda/lib/python3.10/site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in /Users/jacksonglass/Library/r-miniconda/lib/python3.10/site-packages (from kagglehub) (0.1.15)
# Requirement already satisfied: packaging in /Users/jacksonglass/Library/r-miniconda/lib/python3.10/site-packages (from kagglehub) (23.0)
# Requirement already satisfied: requests in /Users/jacksonglass/Library/r-miniconda/lib/python3.10/site-packages (from kagglehub) (2.28.1)
# Requirement already satisfied: protobuf in /Users/jacksonglass/Library/r-miniconda/lib/python3.10/site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (6.33.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jacksonglass/Library/r-miniconda/lib/python3.10/site-packages (from requests->kagglehub) (2025.8.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jacksonglass/Library/r-miniconda/lib/python3.10/site-packages (from requests->kagglehub) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/jacksonglass/Library/r-miniconda/lib/python3.10/site-packages (from requests->kagglehub) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jacksonglass/Library/r-miniconda/lib/python3.10/site-packages (from requests->kagglehub) (1.26.15)

# %%
import kagglehub
import os
import pandas as pd
import numpy as np

dataset_path = kagglehub.dataset_download('stevenpeutz/misinformation-fake-news-text-dataset-79k')

print("Path to dataset files:", dataset_path)

misinfo_fake = os.path.join(dataset_path, 'DataSet_Misinfo_FAKE.csv')
df_fake = pd.read_csv(misinfo_fake)

misinfo_true = os.path.join(dataset_path, 'DataSet_Misinfo_TRUE.csv')
df_true = pd.read_csv(misinfo_true)

print(df_fake.head())
print(df_true.head())
# Out:
# Path to dataset files: /Users/jacksonglass/.cache/kagglehub/datasets/stevenpeutz/misinformation-fake-news-text-dataset-79k/versions/2
#    Unnamed: 0                                               text
# 0           0  Donald Trump just couldn t wish all Americans ...
# 1           1  House Intelligence Committee Chairman Devin Nu...
# 2           2  On Friday, it was revealed that former Milwauk...
# 3           3  On Christmas day, Donald Trump announced that ...
# 4           4  Pope Francis used his annual Christmas Day mes...
#    Unnamed: 0                                               text
# 0           0  The head of a conservative Republican faction ...
# 1           1  Transgender people will be allowed for the fir...
# 2           2  The special counsel investigation of links bet...
# 3           3  Trump campaign adviser George Papadopoulos tol...
# 4           4  President Donald Trump called on the U.S. Post...

# %%
# Combine datasets with label

df_fake['label'] = 0
df_true['label'] = 1

df = pd.concat([df_fake, df_true], ignore_index=True)

df = df.drop(columns=['Unnamed: 0'])

df.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
sample_1 = df.sample(n=1000)
sample_1
# Out:
#                                                     text  label
# 58216  Turkish police have launched operations to tra...      1
# 49552  Airlines operating at Cairo airport were offic...      1
# 32804  Welcome Back to a Bipolar World, Courtesy of a...      0
# 67569  On the Friday edition of Breitbart News Daily,...      1
# 23268  Wed, 26 Oct 2016 23:00 UTC Authorities in Nort...      0
# ...                                                  ...    ...
# 2215   On Thursday, Fox News hack and Donald Trump te...      0
# 65336  On Thursday’s episode of “The Dr. Oz Show,” Do...      1
# 26258  source Add To The Conversation Using Facebook ...      0
# 48645  A group holding more than $10 billion of Puert...      1
# 32904  Slovenia Adds Water To Constitution As Fundame...      0
#
# [1000 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
vectorizer = TfidfVectorizer(
    max_features=1000,
    stop_words='english',
    max_df=0.85,
    min_df=2,
    ngram_range=(1, 2),
    strip_accents='unicode',
    lowercase=True
)

# %%
sample_1 = sample_1.dropna()

# %%
tfidf_matrix = vectorizer.fit_transform(sample_1['text'])
feature_names = vectorizer.get_feature_names_out()

# %%
def find_optimal_clusters(tfidf_matrix, max_clusters=10):
    """
    Standard implementation of elbow method and silhouette score to find optimal number of clusters.
    """
    inertias = []
    silhouette_scores = []
    K_range = range(2, min(max_clusters + 1, (tfidf_matrix.shape)[0]))
    
    print("\nEvaluating optimal number of clusters...")
    for k in K_range:
        kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
        kmeans.fit(tfidf_matrix)
        inertias.append(kmeans.inertia_)
        
        # Calculate silhouette score
        score = silhouette_score(tfidf_matrix, kmeans.labels_, sample_size=min(1000, (tfidf_matrix.shape)[0]))
        silhouette_scores.append(score)
        print(f"  k={k}: silhouette={score:.3f}")
    
    # Suggest k with highest silhouette score
    best_k = K_range[np.argmax(silhouette_scores)]
    print(f"\nSuggested number of clusters: {best_k}")
    
    return best_k

# %%
(tfidf_matrix.shape)[0]
# Out:
# 1000

# %%
n_clusters = find_optimal_clusters(tfidf_matrix, max_clusters=30)

kmeans = KMeans(n_clusters=n_clusters, random_state=1, n_init=10)
cluster_labels = kmeans.fit_predict(tfidf_matrix)
# Out:
# Evaluating optimal number of clusters...
#   k=2: silhouette=0.013
#   k=3: silhouette=0.010
#   k=4: silhouette=0.014
#   k=5: silhouette=0.016
#   k=6: silhouette=0.017
#   k=7: silhouette=0.020
#   k=8: silhouette=0.018
#   k=9: silhouette=0.021
#   k=10: silhouette=0.021
#   k=11: silhouette=0.023
#   k=12: silhouette=0.020
#   k=13: silhouette=0.023
#   k=14: silhouette=0.026
#   k=15: silhouette=0.026
#   k=16: silhouette=0.024
#   k=17: silhouette=0.027
#   k=18: silhouette=0.028
#   k=19: silhouette=0.026
#   k=20: silhouette=0.025
#   k=21: silhouette=0.028
#   k=22: silhouette=0.028
#   k=23: silhouette=0.023
#   k=24: silhouette=0.030
#   k=25: silhouette=0.027
#   k=26: silhouette=0.027
#   k=27: silhouette=0.023
#   k=28: silhouette=0.029
#   k=29: silhouette=0.030
#   k=30: silhouette=0.024
#
# Suggested number of clusters: 29

# %%
cluster_labels
sample_1['cluster'] = cluster_labels

# %%
sample_1[sample_1['cluster'] == 6]
# Out:
#                                                     text  label  cluster
# 23268  Wed, 26 Oct 2016 23:00 UTC Authorities in Nort...      0        6
# 53457  The White House will likely make a decision by...      1        6
# 48778  The U.S. State Department released its annual ...      1        6
# 63738  Important areas  of Hong Kong s  One Country, ...      1        6
# 63502  Hundreds of Tunisians protested on Saturday in...      1        6
# 18091  Hollywood police spokeswoman Miranda Grossman ...      0        6
# 46255  U.S. investigators examining money laundering ...      1        6
# 46004  A former U.S. Justice Department official has ...      1        6
# 49625  Two lawmakers and six consumer advocacy groups...      1        6
# 9322   With all of the stories of, TV hosts involved ...      0        6
# 15966  No, we re not kidding -the money sucker of all...      0        6
# 11123  AG Jeff Sessions is a complete change from the...      0        6
# 56416  The Vatican needs to bring cases of suspected ...      1        6
# 17013  Who could forget the unbelievable standoff in ...      0        6
# 27017  By Maxine Bernstein | The Oregonian/OregonLive...      0        6
# 52799  A federal appeals court fired skeptical questi...      1        6
# 75521  More than 500 staffers from the Justice Depart...      1        6
# 46476  Alan Futerfas, the lawyer Donald Trump Jr. has...      1        6
# 54239  Members of the House Judiciary Committee are c...      1        6
# 61363  An Illinois man accused of abducting a Chinese...      1        6
# 52931  A U.S. congressional committee has launched an...      1        6
# 23535  Dispatches from Wolf Country –Sitting in my ca...      0        6
# 51990  The U.S. Department of Homeland Security will ...      1        6
# 60481  The U.N. subcommittee on torture prevention ha...      1        6
# 69077  A federal judge sentenced an Illinois immigrat...      1        6
# 54810  Federal Reserve Chair Janet Yellen will appear...      1        6
# 778    Because there s totally nothing else better fo...      0        6
# 21788  21st Century Wire Yesterday, Judge Anna Brown ...      0        6

# %%
for cluster in range(n_clusters):
    cluster_mask = sample_1['cluster'] == cluster
    cluster_data = sample_1[cluster_mask]
    size = len(cluster_data)
    fake_fraction = (cluster_data['label']==0).sum() / size

    print(f'Cluster {cluster}: Size={size}, Fake Fraction={fake_fraction:.2f}')
# Out:
# Cluster 0: Size=10, Fake Fraction=0.80
# Cluster 1: Size=47, Fake Fraction=0.15
# Cluster 2: Size=102, Fake Fraction=0.64
# Cluster 3: Size=16, Fake Fraction=0.12
# Cluster 4: Size=23, Fake Fraction=0.43
# Cluster 5: Size=28, Fake Fraction=0.50
# Cluster 6: Size=28, Fake Fraction=0.36
# Cluster 7: Size=26, Fake Fraction=0.58
# Cluster 8: Size=99, Fake Fraction=0.47
# Cluster 9: Size=22, Fake Fraction=0.05
# Cluster 10: Size=20, Fake Fraction=0.15
# Cluster 11: Size=69, Fake Fraction=0.86
# Cluster 12: Size=26, Fake Fraction=0.65
# Cluster 13: Size=25, Fake Fraction=0.88
# Cluster 14: Size=60, Fake Fraction=0.45
# Cluster 15: Size=21, Fake Fraction=0.67
# Cluster 16: Size=35, Fake Fraction=0.51
# Cluster 17: Size=32, Fake Fraction=0.72
# Cluster 18: Size=20, Fake Fraction=0.75
# Cluster 19: Size=36, Fake Fraction=0.75
# Cluster 20: Size=25, Fake Fraction=0.12
# Cluster 21: Size=25, Fake Fraction=0.92
# Cluster 22: Size=24, Fake Fraction=0.58
# Cluster 23: Size=57, Fake Fraction=0.30
# Cluster 24: Size=24, Fake Fraction=0.29
# Cluster 25: Size=28, Fake Fraction=0.93
# Cluster 26: Size=31, Fake Fraction=0.16
# Cluster 27: Size=8, Fake Fraction=0.88
# Cluster 28: Size=33, Fake Fraction=0.82

# %%
feature_names
# Out:
# array(['000', '10', '100', '11', '12', '13', '14', '15', '17', '18', '20',
#        '2008', '2012', '2013', '2014', '2015', '2016', '2017', '21', '25',
#        '28', '30', '40', '50', '60', 'able', 'abortion', 'access',
#        'according', 'account', 'accused', 'act', 'action', 'actions',
#        'actually', 'added', 'adding', 'address', 'administration',
#        'adviser', 'agencies', 'agency', 'agenda', 'ago', 'agreed',
#        'agreement', 'ahead', 'air', 'al', 'aleppo', 'allegations',
#        'alleged', 'allies', 'allow', 'allowed', 'america', 'american',
#        'americans', 'announced', 'anti', 'appeared', 'appears', 'april',
#        'arabia', 'area', 'areas', 'armed', 'army', 'arrested', 'article',
#        'ask', 'asked', 'asking', 'attack', 'attacks', 'attempt',
#        'attention', 'attorney', 'attorney general', 'august',
#        'authorities', 'authority', 'available', 'away', 'backed', 'bad',
#        'ballot', 'ban', 'bank', 'barack', 'barack obama', 'base', 'based',
#        'battle', 'began', 'believe', 'believed', 'bernie',
#        'bernie sanders', 'best', 'better', 'big', 'biggest', 'billion',
#        'black', 'board', 'body', 'book', 'border', 'born', 'break',
#        'breitbart', 'briefing', 'bring', 'britain', 'british', 'brought',
#        'budget', 'build', 'building', 'bush', 'business', 'california',
#        'called', 'calling', 'calls', 'came', 'campaign', 'candidate',
#        'candidates', 'capital', 'car', 'care', 'case', 'cases', 'cash',
#        'cause', 'center', 'central', 'century', 'certain', 'certainly',
#        'chairman', 'chance', 'change', 'charge', 'charges', 'chief',
#        'child', 'children', 'china', 'chinese', 'choice', 'christian',
#        'church', 'citizens', 'city', 'civil', 'claim', 'claimed',
#        'claims', 'class', 'clear', 'clearly', 'climate', 'clinton',
#        'clinton campaign', 'close', 'cnn', 'coalition', 'college', 'com',
#        'come', 'comes', 'comey', 'coming', 'comment', 'comments',
#        'committee', 'common', 'community', 'companies', 'company',
#        'concerns', 'conference', 'confirmed', 'conflict', 'congress',
#        'congressional', 'conservative', 'consider', 'considered',
#        'continue', 'continued', 'control', 'corruption', 'cost', 'couldn',
#        'council', 'countries', 'country', 'county', 'course', 'court',
#        'cover', 'create', 'created', 'crime', 'crimes', 'criminal',
#        'crisis', 'critical', 'cruz', 'current', 'cut', 'daily',
#        'dangerous', 'data', 'daughter', 'david', 'day', 'days', 'dead',
#        'deal', 'death', 'debate', 'decades', 'december', 'decided',
#        'decision', 'declared', 'declined', 'deep', 'defense', 'delegates',
#        'democracy', 'democrat', 'democratic', 'democrats', 'denied',
#        'department', 'deputy', 'described', 'despite', 'development',
#        'did', 'didn', 'died', 'different', 'difficult', 'director',
#        'discuss', 'district', 'documents', 'does', 'doesn', 'doing',
#        'dollars', 'don', 'don know', 'don want', 'donald', 'donald trump',
#        'dr', 'drug', 'earlier', 'early', 'east', 'eastern', 'economic',
#        'economy', 'education', 'effect', 'effort', 'efforts', 'elected',
#        'election', 'elections', 'email', 'emails', 'employees', 'end',
#        'energy', 'enforcement', 'entire', 'especially', 'establishment',
#        'eu', 'europe', 'european', 'european union', 'event', 'events',
#        'evidence', 'exactly', 'example', 'executive', 'expected',
#        'experience', 'experts', 'face', 'facebook', 'fact', 'failed',
#        'fake', 'fall', 'families', 'family', 'far', 'father', 'fbi',
#        'fear', 'featured', 'featured image', 'february', 'federal',
#        'feel', 'fellow', 'fight', 'fighting', 'film', 'final',
#        'financial', 'fired', 'firm', 'florida', 'flynn', 'focus',
#        'follow', 'following', 'food', 'force', 'forced', 'forces',
#        'foreign', 'foreign policy', 'forward', 'foundation', 'fox',
#        'fox news', 'france', 'fraud', 'free', 'freedom', 'french',
#        'friday', 'friends', 'fund', 'funding', 'future', 'game', 'gave',
#        'general', 'george', 'germany', 'getting', 'getty', 'getty images',
#        'given', 'giving', 'global', 'god', 'goes', 'going', 'gold',
#        'gone', 'good', 'gop', 'got', 'government', 'governor', 'great',
#        'ground', 'group', 'groups', 'growing', 'gun', 'guy', 'half',
#        'hand', 'hands', 'happen', 'happened', 'hard', 'having', 'head',
#        'health', 'healthcare', 'hear', 'heard', 'hearing', 'held', 'help',
#        'helped', 'helping', 'high', 'higher', 'hillary',
#        'hillary clinton', 'history', 'hit', 'hold', 'holding', 'home',
#        'hope', 'host', 'hours', 'house', 'https', 'human', 'human rights',
#        'hundreds', 'idea', 'illegal', 'image', 'images', 'immediately',
#        'immigrants', 'immigration', 'important', 'include', 'included',
#        'including', 'increase', 'independent', 'india', 'industry',
#        'influence', 'information', 'inside', 'instead', 'intelligence',
#        'interests', 'international', 'internet', 'interview',
#        'investigation', 'involved', 'iran', 'iraq', 'iraqi', 'isis',
#        'islamic', 'islamic state', 'island', 'isn', 'israel', 'issue',
#        'issued', 'issues', 'james', 'january', 'job', 'jobs', 'joe',
#        'john', 'johnson', 'journalists', 'judge', 'july', 'june', 'just',
#        'justice', 'kelly', 'kerry', 'key', 'kill', 'killed', 'kind',
#        'king', 'knew', 'know', 'known', 'knows', 'korea', 'kurdish',
#        'labor', 'land', 'large', 'largely', 'largest', 'late', 'later',
#        'latest', 'law', 'law enforcement', 'lawmakers', 'laws', 'lawyer',
#        'lead', 'leader', 'leaders', 'leading', 'leave', 'led', 'left',
#        'legal', 'legislation', 'let', 'letter', 'level', 'liberal',
#        'life', 'light', 'like', 'likely', 'line', 'list', 'little',
#        'live', 'lives', 'living', 'll', 'local', 'london', 'long',
#        'longer', 'look', 'looking', 'looks', 'lost', 'lot', 'love', 'low',
#        'macron', 'mainstream', 'major', 'majority', 'make', 'makes',
#        'making', 'man', 'march', 'mark', 'market', 'mass', 'massive',
#        'matter', 'maybe', 'mccain', 'mean', 'means', 'measure', 'media',
#        'medical', 'meet', 'meeting', 'member', 'members', 'men',
#        'message', 'met', 'mexico', 'michael', 'michigan', 'middle',
#        'middle east', 'mike', 'militants', 'military', 'million',
#        'millions', 'mind', 'minister', 'ministry', 'minutes', 'moment',
#        'monday', 'money', 'month', 'months', 'moore', 'morning', 'moscow',
#        'mother', 'movement', 'mr', 'mr obama', 'mr trump', 'mrs',
#        'mrs clinton', 'ms', 'muslim', 'muslims', 'nation', 'national',
#        'national security', 'nations', 'nbc', 'near', 'nearly', 'need',
#        'needed', 'needs', 'network', 'new', 'new york', 'news', 'night',
#        'nomination', 'nominee', 'non', 'north', 'nov', 'november',
#        'nuclear', 'number', 'numbers', 'obama', 'obama administration',
#        'obamacare', 'october', 'offered', 'office', 'officer', 'officers',
#        'official', 'officials', 'oil', 'old', 'online', 'open',
#        'operation', 'opinion', 'opposed', 'opposition', 'order', 'oregon',
#        'organization', 'organizations', 'outside', 'page', 'paid',
#        'pakistan', 'parents', 'paris', 'park', 'parties', 'party',
#        'passed', 'past', 'paul', 'pay', 'peace', 'pence', 'people',
#        'percent', 'period', 'person', 'personal', 'phone', 'photo', 'pic',
#        'pic twitter', 'place', 'plan', 'planned', 'plans', 'play',
#        'point', 'points', 'police', 'policies', 'policy', 'political',
#        'politicians', 'politics', 'poll', 'polls', 'popular', 'position',
#        'possible', 'post', 'posted', 'potential', 'power', 'powerful',
#        'presidency', 'president', 'president barack', 'president donald',
#        'president obama', 'president trump', 'presidential',
#        'presidential election', 'press', 'pressure', 'pretty', 'previous',
#        'primary', 'prime', 'prime minister', 'private', 'pro', 'probably',
#        'problem', 'problems', 'process', 'professor', 'program',
#        'project', 'protect', 'protest', 'protesters', 'protests',
#        'provide', 'public', 'published', 'putin', 'question', 'questions',
#        'quickly', 'quite', 'race', 'radio', 'raised', 'rally', 'read',
#        'ready', 'real', 'really', 'reason', 'reasons', 'received',
#        'recent', 'recently', 'record', 'records', 'refugees', 'region',
#        'related', 'relations', 'relationship', 'release', 'released',
#        'religious', 'remain', 'remains', 'remarks', 'report', 'reported',
#        'reporters', 'reporting', 'reports', 'representative',
#        'representatives', 'republican', 'republicans', 'research',
#        'responded', 'response', 'responsible', 'result', 'results',
#        'return', 'reuters', 'review', 'rich', 'right', 'rights', 'risk',
#        'role', 'room', 'rubio', 'rule', 'rules', 'ruling', 'run',
#        'running', 'russia', 'russian', 'russians', 'ryan', 'safe', 'said',
#        'said statement', 'san', 'sanctions', 'sanders', 'saturday',
#        'saudi', 'saudi arabia', 'save', 'saw', 'say', 'saying', 'says',
#        'school', 'science', 'second', 'secret', 'secretary',
#        'secretary state', 'security', 'seeking', 'seen', 'senate',
#        'senator', 'senior', 'sense', 'sent', 'september', 'series',
#        'serve', 'served', 'server', 'service', 'services', 'set', 'seven',
#        'sex', 'sexual', 'share', 'shooting', 'short', 'shot', 'showed',
#        'shows', 'sides', 'sign', 'signed', 'significant', 'similar',
#        'simply', 'single', 'situation', 'small', 'social', 'social media',
#        'society', 'son', 'soon', 'source', 'sources', 'south', 'speak',
#        'speaking', 'special', 'speech', 'spent', 'spoke', 'spokesman',
#        'spokeswoman', 'staff', 'stand', 'standing', 'star', 'start',
#        'started', 'state', 'state department', 'statement', 'states',
#        'stay', 'step', 'stop', 'stories', 'story', 'street', 'strong',
#        'students', 'study', 'sunday', 'support', 'supported',
#        'supporters', 'supreme', 'supreme court', 'sure', 'syria',
#        'syrian', 'taken', 'taking', 'talk', 'talking', 'talks', 'tax',
#        'team', 'television', 'tell', 'telling', 'term', 'terms',
#        'terrorism', 'terrorist', 'texas', 'thing', 'things', 'think',
#        'thought', 'thousands', 'threat', 'thursday', 'ties', 'time',
#        'times', 'today', 'told', 'took', 'total', 'town', 'trade',
#        'transition', 'tried', 'troops', 'true', 'trump',
#        'trump administration', 'trump campaign', 'trump said', 'trust',
#        'truth', 'try', 'trying', 'tuesday', 'turkey', 'turkish', 'turn',
#        'turned', 'tv', 'twitter', 'twitter com', 'ukraine', 'understand',
#        'union', 'united', 'united states', 'university', 'usa', 'use',
#        'used', 'using', 've', 'vice', 'vice president', 'victims',
#        'victory', 'video', 'view', 'views', 'violence', 'violent',
#        'virginia', 'visit', 'vladimir', 'vladimir putin', 'vote', 'voted',
#        'voters', 'votes', 'voting', 'wall', 'want', 'wanted', 'wants',
#        'war', 'washington', 'washington post', 'wasn', 'watch', 'water',
#        'way', 'ways', 'weapons', 'website', 'wednesday', 'week',
#        'weekend', 'weeks', 'went', 'west', 'western', 'white',
#        'white house', 'wife', 'wikileaks', 'win', 'woman', 'women', 'won',
#        'word', 'words', 'work', 'worked', 'workers', 'working', 'world',
#        'worse', 'worth', 'wouldn', 'wrong', 'wrote', 'year', 'year old',
#        'years', 'years ago', 'yes', 'york', 'york times', 'young'],
#       dtype=object)
